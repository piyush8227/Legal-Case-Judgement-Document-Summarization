# %%
import numpy as np
import pandas as pd

# %%
labelled_data = pd.read_csv("New_Labelled_data_3.csv")
labelled_data.head()
# Out:
#                      Label  Score
# 0  special leave petitions  33.66
# 1              appointment  43.53
# 2                    civil  36.01
# 3  special leave petitions  64.04
# 4              appointment  28.79

# %%
data = pd.read_csv("Summarized_Judgments.csv")
data.head()
# Out:
#                                             JUDGMENT  \
# 0   J U D G M E N T CRIMINAL APPEAL NO.   943    ...
# 1   JUDGMENT O R D E R (arising out of SPECIAL LE...
# 2   JUDGMENT O R D E R TRANSFER PETITION(CRL.)NO....
# 3   J U D G M E N T NON-REPORTABLE CRIMINAL APPEA...
# 4   O R D E R Leave granted. Heard the counsel fo...
#
#                                      Summarized_text
# 0  Dr. ARIJIT PASAYAT, J. challenges the order pa...
# 1  The High Court has dismissed the same by the i...
# 2  Petition filed under Section 406, Cr.P.C. by t...
# 3  The complainant Rajeshwari lodged a complaint ...
# 4  Karnataka Inams Abolition Laws (Amendment)  Ac...

# %%
data_1 = data.copy()

# %%
data_1 = data_1.iloc[1360:1668]

# %%
data_1.reset_index(inplace=True)

# %%
labelled_data
# Out:
#                        Label  Score
# 0    special leave petitions  33.66
# 1                appointment  43.53
# 2                      civil  36.01
# 3    special leave petitions  64.04
# 4                appointment  28.79
# ..                       ...    ...
# 303  special leave petitions  31.02
# 304  special leave petitions  55.80
# 305                    civil  42.59
# 306  special leave petitions  24.96
# 307                    civil  60.98
#
# [308 rows x 2 columns]

# %%
data_1['Labels'] = labelled_data['Label']
data_1['Scores'] = labelled_data['Score']

data_1.head()
# Out:
#    index                                           JUDGMENT  \
# 0   1360   CRIMINAL APPELLATE JURISDICTION : Criminal Ap...
# 1   1361   J U D G M E N T Leave granted.  Heard learned...
# 2   1362   JUDGMENT O R D E R NON-REPORTABLE CIVIL APPEA...
# 3   1363   O R D E R Leave granted. We have heard the le...
# 4   1364   JUDGMENT ORDER In the above petitions an appl...
#
#                                      Summarized_text                   Labels  \
# 0  Bail was granted by the Sessions Judge after h...  special leave petitions
# 1  Second defendant is the appellant. Suit for pa...              appointment
# 2  This appeal is directed against an order dated...                    civil
# 3  Notificaticn under Section 4[l] of the Land Ac...  special leave petitions
# 4  The High Court has directed the Secretary to t...              appointment
#
#    Scores
# 0   33.66
# 1   43.53
# 2   36.01
# 3   64.04
# 4   28.79

# %%
data_1.to_csv('')
